# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the data
data=pd.read_csv('/content/EastWestAirlines.csv')

# %%
df=data.copy()

# %%
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %% [markdown]
# ### **EDA**

# %%
#checking null values
data.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
#checking duplicated values
data.duplicated().sum()
# Out:
# 0

# %%
#removing unneccessery columns
data.drop("ID#",axis=1,inplace=True)

# %%
data.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
data1=data.copy()
data2=data.copy()
data3=data.copy()

# %% [markdown]
# ## **Hierarchical Clustering**

# %%
#For hierarchical we need to scale the data ,for that am using MinMaxscaler.
#For this am using data1
from sklearn.preprocessing import MinMaxScaler

# %%
data1_bs=data1

# %%
mm=MinMaxScaler()

# %%
data1.iloc[:,:]=mm.fit_transform(data1.iloc[:,:])
# Out:
# <ipython-input-17-7527870bce9c>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data1.iloc[:,:]=mm.fit_transform(data1.iloc[:,:])

# %%
data1
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#creating dendgrom
import scipy.cluster.hierarchy as sch
dendogram=sch.dendrogram(sch.linkage(data1,method='complete'))

# %%
#for hierarchical Clustering we use Agglomeritive which is available on sklearn.library
from sklearn.cluster import AgglomerativeClustering
ac=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='complete')
ac.fit(data1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=5)

# %%
ac.fit_predict(data1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([0, 0, 0, ..., 2, 0, 0])

# %%
data1['clusters']=ac.fit_predict(data1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
data1
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df['clusters']=ac.fit_predict(data1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.iloc[:,[0,-1]]
# Out:
#        ID#  clusters
# 0        1         0
# 1        2         0
# 2        3         0
# 3        4         0
# 4        5         1
# ...    ...       ...
# 3994  4017         2
# 3995  4018         2
# 3996  4019         2
# 3997  4020         0
# 3998  4021         0
#
# [3999 rows x 2 columns]

# %%
df['clusters'].value_counts()
# Out:
# 0    2495
# 2    1144
# 1     325
# 4      31
# 3       4
# Name: clusters, dtype: int64

# %% [markdown]
# ### **2. Kmean Clustering**

# %%
#For Kmean clustering am using Data2 which is well structured and we dont't want to do EDA,already Done on that data.
#am using standardscaler for scaling
from sklearn.preprocessing import StandardScaler
ss=StandardScaler ()

# %%
data_bs1=data2

# %%
#standardizing values
data_bs1.iloc[:,:]=ss.fit_transform(data_bs1.iloc[:,:])

# %%
data_bs1
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range(1,11):
  kmean=KMeans(n_clusters=i,random_state=0)
  kmean.fit(data_bs1)
  wcss.append(kmean.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
sns.lineplot(x=range(1,11),y=wcss)
# Out:
# <Axes: >

# %%
#from the above plot we can observe that the line is going to similar at a point 7.
#so we can take the K value as 7
#Now building the model
kmean1=KMeans(7,random_state=0)
kmean1.fit(data_bs1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=7, random_state=0)

# %%
kmean1.fit_predict(data_bs1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 2, 2, ..., 0, 1, 1], dtype=int32)

# %%
kmean1.labels_
# Out:
# array([2, 2, 2, ..., 0, 1, 1], dtype=int32)

# %%
df1=df.iloc[:,:-1]

# %%
df1['labels']=kmean1.labels_

# %%
df1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df1.iloc[:,[0,-1]]
# Out:
#        ID#  labels
# 0        1       2
# 1        2       2
# 2        3       2
# 3        4       2
# 4        5       0
# ...    ...     ...
# 3994  4017       1
# 3995  4018       1
# 3996  4019       0
# 3997  4020       1
# 3998  4021       1
#
# [3999 rows x 2 columns]

# %%
# The silhouette coefficient or silhouette score kmeans is a measure of how similar a data point is within-cluster (cohesion) compared to other clusters (separation).
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
silohout_score=silhouette_score(data_bs1,kmean1.labels_)

# %%
silohout_score
# Out:
# 0.22085896619040385

# %% [markdown]
# ## **3. DBSCAN(Density-based spatial clustering of applications with noise)**

# %%
#for DBSCAN we need well structured data,in the first i have done EDA and took copy of data and stored that data As Data3
#Now am using that data for this DBSCAN
#before moving first we need to standardize the numerical data.
#for that am using standardscaler
data_bs2=data3

# %%
#standardizing the
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
data_bs2.iloc[:,:]=ss.fit_transform(data_bs2)

# %%
data_bs2
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# To Know The Optimal value of Epesilon we can use K-Distance Graph.
# The distance variable contains an array of distances between a data point and its nearest data point for all data points in the dataset.
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(data_bs2)
distances, indices = nbrs.kneighbors(data_bs2)

# %%
distances=np.sort(distances,axis=0)
distances=distances[:,1]
plt.plot(distances)

# %%
## The optimum value of epsilon is at the point of maximum curvature in the K-Distance Graph, which is 2.
#importing the model and building the model
from sklearn.cluster import DBSCAN
db=DBSCAN(eps=2,min_samples=4)

# %%
db.fit(data_bs2)
# Out:
# DBSCAN(eps=2, min_samples=4)

# %%
db.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
df3=df.iloc[:,:-1]

# %%
df3['cluster']=db.labels_

# %%
df3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df3.iloc[:,[0,-1]]
# Out:
#        ID#  cluster
# 0        1        0
# 1        2        0
# 2        3        0
# 3        4        0
# 4        5        1
# ...    ...      ...
# 3994  4017        1
# 3995  4018        1
# 3996  4019        1
# 3997  4020        0
# 3998  4021        0
#
# [3999 rows x 2 columns]

# %%
df3['cluster'].value_counts()
# Out:
#  0    2453
#  1    1334
# -1     167
#  3      16
#  2       9
#  5       7
#  6       5
#  4       4
#  7       4
# Name: cluster, dtype: int64

# %%
# Outlier Detection.
# The most amazing thing about DBSCAN is that it separates noise from the dataset pretty well. Here, 0, 1 and 2 etc are the different clusters, and -1 is the noise.
df3[df3['cluster']==-1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8        9   443003           0          3          2          1         1753
# 50      51   108137           0          1          1          1         6368
# 65      66    53914           0          3          1          1        33767
# 70      72    84409        5031          2          1          1        15436
# 87      90   609477           0          3          1          1        21422
# ...    ...      ...         ...        ...        ...        ...          ...
# 3846  3869    97510        1678          5          1          1        71609
# 3883  3906   126167           0          5          1          1       190160
# 3911  3934    55922        2273          1          1          1         8104
# 3917  3940   130748           0          4          1          1        65510
# 3934  3957    76595           0          1          1          1        10577
#
# ...
